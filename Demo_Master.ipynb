# %%
import ecdf_util
import gen_util
import mda_util
import quantile_util
import plot_util
import os

from IPython.core.display import Image
#import empiri_model_util as emu

HOME_DIR = os.getcwd()
# Out:
# /usr/lib/pymodules/python2.7/mpl_toolkits/__init__.py:2: UserWarning: Module dap was already imported from None, but /usr/lib/python2.7/dist-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
#intall requirements
#gen_util.prep_env()

#Curation Step
#grab the needed repos. Does clone/pull depending on if you already have the code
gen_util.setup_repos()
curation_ret_code = gen_util.curate()
# Out:
# TheQuakers folder already exists, pulling instead
# tristan_quakers pull complete
# .....
#
# tristan_curators folder already exists, pulling instead
# tristan_curators pull complete
# Begining raw curation
# Raw Curation complete

# %%
#Inspecing our data
plot_util.plot_quakes((1998,2013),(9,9),10)
# Out:
# working with the following years [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# working with the following years [1998]
# working with the following years [1999]
# working with the following years [2000]
# working with the following years [2001]
# working with the following years [2002]
# working with the following years [2003]
# working with the following years [2004]
# working with the following years [2005]
# working with the following years [2006]
# working with the following years [2007]
# working with the following years [2008]
# working with the following years [2009]
# working with the following years [2010]
# working with the following years [2011]
# working with the following years [2012]
# working with the following years [2013]

# %%
#ECDF demo
#%matplotlib inline

#Generate the plots
ecdf_util.generate_ecdf_plots()
#ecdf_util.show_plots() #Doesn't work, so doing it below

Image(filename=os.path.join(HOME_DIR, 'tristan_quakers/ECDF/plot.png'))
# Out:
# ECDF generation failed with code 256

# %%
#Generate the plots #TAKES A LONG TIME
mda_util.generate_MDA_plots()

#MDA demo
#ecdf_util.show_plots() #Doesn't work, so doing it below
# Out:
# Starting MDA plot generation via MDAs-final.R
# MDA plots generated!
# 0

# %%
#Show MDADiv model plot
#mda_util.show_MDAdiv_plot()
Image(filename=os.path.join(HOME_DIR, 'tristan_quakers/ScaledMDA/ErrorSMDADiv.jpeg'))

# %%
#Show MDASub plot
#mda_util.show_MDAsub_plot()
Image(filename=os.path.join(HOME_DIR, 'tristan_quakers/ScaledMDA/ErrorSMDAsub.jpeg'))

# %%
quantile_util.generate_quantile_plots()
#add plotting here

# %%
#Class Response plot
#http://amx01.github.io/?repro3#
